# %% [markdown]
# ---
#
# _You are currently looking at **version 1.1** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# %% [markdown]
# # Assignment 4 - Hypothesis Testing
# This assignment requires more individual learning than previous assignments - you are encouraged to check out the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/) to find functions or methods you might not have used yet, or ask questions on [Stack Overflow](http://stackoverflow.com/) and tag them as pandas and python related. And of course, the discussion forums are open for interaction with your peers and the course staff.
#
# Definitions:
# * A _quarter_ is a specific three month period, Q1 is January through March, Q2 is April through June, Q3 is July through September, Q4 is October through December.
# * A _recession_ is defined as starting with two consecutive quarters of GDP decline, and ending with two consecutive quarters of GDP growth.
# * A _recession bottom_ is the quarter within a recession which had the lowest GDP.
# * A _university town_ is a city which has a high percentage of university students compared to the total population of the city.
#
# **Hypothesis**: University towns have their mean housing prices less effected by recessions. Run a t-test to compare the ratio of the mean price of houses in university towns the quarter before the recession starts compared to the recession bottom. (`price_ratio=quarter_before_recession/recession_bottom`)
#
# The following data files are available for this assignment:
# * From the [Zillow research data site](http://www.zillow.com/research/data/) there is housing data for the United States. In particular the datafile for [all homes at a city level](http://files.zillowstatic.com/research/public/City/City_Zhvi_AllHomes.csv), ```City_Zhvi_AllHomes.csv```, has median home sale prices at a fine grained level.
# * From the Wikipedia page on college towns is a list of [university towns in the United States](https://en.wikipedia.org/wiki/List_of_college_towns#College_towns_in_the_United_States) which has been copy and pasted into the file ```university_towns.txt```.
# * From Bureau of Economic Analysis, US Department of Commerce, the [GDP over time](http://www.bea.gov/national/index.htm#gdp) of the United States in current dollars (use the chained value in 2009 dollars), in quarterly intervals, in the file ```gdplev.xls```. For this assignment, only look at GDP data from the first quarter of 2000 onward.
#
# Each function in this assignment below is worth 10%, with the exception of ```run_ttest()```, which is worth 50%.

# %%
# This dictionary maps state names to two letter acronyms
states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}

# %%
def get_list_of_university_towns():
    '''Returns a DataFrame of towns and the states they are in from the 
    university_towns.txt list. '''
    
    # import list
    ut_df = pd.read_table('university_towns.txt', header = None, names = ['RegionName'])

    # Assign States
    ut_df['State'] = None
    for index, row in ut_df.iterrows():
        if row['RegionName'][-6:] == '[edit]':
            state = row[0][:-6]
            row['State'] = state
        else: 
            row['State'] = state

    # Clean Data
    for index, row in ut_df.iterrows():
        if row['RegionName'][-6:] == '[edit]':
            ut_df.drop(index,inplace = True)

    ut_df['RegionName'] = ut_df['RegionName'].str.split('(').str[0].str.strip()    
    ut_df = ut_df[['State', 'RegionName']]

    return ut_df

# %%
def get_list_of_GDP_recession():
    '''Returns a DataFrame of GDP by years and quarters from gdplev.xls. Includes columns detailing
    whether the GDP is deline, in recession, a start quarter of recession, or an end quarter of recession '''
        
    #import and clean
    gdp_df = pd.read_excel('gdplev.xls', skiprows = 7)
    gdp_df = gdp_df.iloc[:, 4:-1]
    gdp_df.rename(columns = {'Unnamed: 4':'Quarter', 'Unnamed: 5':'GDP in billions of current dollars', 'Unnamed: 6': 'GDP'}, inplace = True)
    gdp_df.drop('GDP in billions of current dollars', axis = 1, inplace = True)

    #get diffs column
    gdp_df['diffs'] = np.where(gdp_df['GDP'].diff() > 0, 'increase', 'decline')

    #set In Recession column
    gdp_df['In Recession'] = False
    for index, row in gdp_df.iterrows():
        
        #set variables
        if index+1 in gdp_df.index:
            nex = gdp_df.loc[index+1]
        else: nex = None
        cur = gdp_df.loc[index]
        if index-1 in gdp_df.index:
            prv = gdp_df.loc[index-1]
        else: prv = None

        # assign True if in recession (begins with two periods of decline and ends after two periods of growth)
        if (
            index+1 in gdp_df.index
                #next and current are decline
            and ((nex['diffs'] == 'decline') and (cur['diffs'] == 'decline'))
                #previous is in recession and current or next is decline
            or ((prv['In Recession'] == True) and ((cur['diffs'] == 'decline') or (nex['diffs'] == 'decline') or (prv['diffs'] == 'decline') or (gdp_df.loc[index-2]['diffs'] == 'decline'))) 
           ):
            gdp_df.loc[index,'In Recession'] = True
    
    #set Recession Start column
    gdp_df['Recession Start'] = False
    for index, row in gdp_df.iterrows():
        if(
            ((index-1 not in gdp_df.index) or (gdp_df.loc[index-1,'In Recession'] == False))
            and (gdp_df.loc[index,'In Recession'] == True)
        ):
            gdp_df.loc[index, 'Recession Start'] = True

    #set Recession End column
    gdp_df['Recession End'] = False
    for index, row in gdp_df.iterrows():
        if(
            ((index+1 not in gdp_df.index) or (gdp_df.loc[index+1,'In Recession'] == False))
            and (gdp_df.loc[index,'In Recession'] == True)
        ):
            gdp_df.loc[index, 'Recession End'] = True
    
    return gdp_df

get_list_of_GDP_recession()
# Out:
#     Quarter      GDP     diffs In Recession Recession Start Recession End
# 0    1947q1   1934.5   decline         True            True         False
# 1    1947q2   1932.3   decline         True           False         False
# 2    1947q3   1930.3   decline         True           False         False
# 3    1947q4   1960.7  increase         True           False         False
# 4    1948q1   1989.5  increase         True           False          True
# 5    1948q2   2021.9  increase        False           False         False
# 6    1948q3   2033.2  increase        False           False         False
# 7    1948q4   2035.3  increase        False           False         False
# 8    1949q1   2007.5   decline         True            True         False
# 9    1949q2   2000.8   decline         True           False         False
# 10   1949q3   2022.8  increase         True           False         False
# 11   1949q4   2004.7   decline         True           False         False
# 12   1950q1   2084.6  increase         True           False         False
# 13   1950q2   2147.6  increase         True           False          True
# 14   1950q3   2230.4  increase        False           False         False
# 15   1950q4   2273.4  increase        False           False         False
# 16   1951q1   2304.5  increase        False           False         False
# 17   1951q2   2344.5  increase        False           False         False
# 18   1951q3   2392.8  increase        False           False         False
# 19   1951q4   2398.1  increase        False           False         False
# 20   1952q1   2423.5  increase        False           False         False
# 21   1952q2   2428.5  increase        False           False         False
# 22   1952q3   2446.1  increase        False           False         False
# 23   1952q4   2526.4  increase        False           False         False
# 24   1953q1   2573.4  increase        False           False         False
# 25   1953q2   2593.5  increase        False           False         False
# 26   1953q3   2578.9   decline         True            True         False
# 27   1953q4   2539.8   decline         True           False         False
# 28   1954q1   2528.0   decline         True           False         False
# 29   1954q2   2530.7  increase         True           False         False
# 30   1954q3   2559.4  increase         True           False          True
# 31   1954q4   2609.3  increase        False           False         False
# 32   1955q1   2683.8  increase        False           False         False
# 33   1955q2   2727.5  increase        False           False         False
# 34   1955q3   2764.1  increase        False           False         False
# 35   1955q4   2780.8  increase        False           False         False
# 36   1956q1   2770.0   decline        False           False         False
# 37   1956q2   2792.9  increase        False           False         False
# 38   1956q3   2790.6   decline        False           False         False
# 39   1956q4   2836.2  increase        False           False         False
# 40   1957q1   2854.5  increase        False           False         False
# 41   1957q2   2848.2   decline        False           False         False
# 42   1957q3   2875.9  increase        False           False         False
# 43   1957q4   2846.4   decline         True            True         False
# 44   1958q1   2772.7   decline         True           False         False
# 45   1958q2   2790.9  increase         True           False         False
# 46   1958q3   2855.5  increase         True           False          True
# 47   1958q4   2922.3  increase        False           False         False
# 48   1959q1   2976.6  increase        False           False         False
# 49   1959q2   3049.0  increase        False           False         False
# 50   1959q3   3043.1   decline        False           False         False
# 51   1959q4   3055.1  increase        False           False         False
# 52   1960q1   3123.2  increase        False           False         False
# 53   1960q2   3111.3   decline        False           False         False
# 54   1960q3   3119.1  increase        False           False         False
# 55   1960q4   3081.3   decline        False           False         False
# 56   1961q1   3102.3  increase        False           False         False
# 57   1961q2   3159.9  increase        False           False         False
# 58   1961q3   3212.6  increase        False           False         False
# 59   1961q4   3277.7  increase        False           False         False
# 60   1962q1   3336.8  increase        False           False         False
# 61   1962q2   3372.7  increase        False           False         False
# 62   1962q3   3404.8  increase        False           False         False
# 63   1962q4   3418.0  increase        False           False         False
# 64   1963q1   3456.1  increase        False           False         False
# 65   1963q2   3501.1  increase        False           False         False
# 66   1963q3   3569.5  increase        False           False         False
# 67   1963q4   3595.0  increase        False           False         False
# 68   1964q1   3672.7  increase        False           False         False
# 69   1964q2   3716.4  increase        False           False         False
# 70   1964q3   3766.9  increase        False           False         False
# 71   1964q4   3780.2  increase        False           False         False
# 72   1965q1   3873.5  increase        False           False         False
# 73   1965q2   3926.4  increase        False           False         False
# 74   1965q3   4006.2  increase        False           False         False
# 75   1965q4   4100.6  increase        False           False         False
# 76   1966q1   4201.9  increase        False           False         False
# 77   1966q2   4219.1  increase        False           False         False
# 78   1966q3   4249.2  increase        False           False         False
# 79   1966q4   4285.6  increase        False           False         False
# 80   1967q1   4324.9  increase        False           False         False
# 81   1967q2   4328.7  increase        False           False         False
# 82   1967q3   4366.1  increase        False           False         False
# 83   1967q4   4401.2  increase        False           False         False
# 84   1968q1   4490.6  increase        False           False         False
# 85   1968q2   4566.4  increase        False           False         False
# 86   1968q3   4599.3  increase        False           False         False
# 87   1968q4   4619.8  increase        False           False         False
# 88   1969q1   4691.6  increase        False           False         False
# 89   1969q2   4706.7  increase        False           False         False
# 90   1969q3   4736.1  increase        False           False         False
# 91   1969q4   4715.5   decline         True            True         False
# 92   1970q1   4707.1   decline         True           False         False
# 93   1970q2   4715.4  increase         True           False         False
# 94   1970q3   4757.2  increase         True           False         False
# 95   1970q4   4708.3   decline         True           False         False
# 96   1971q1   4834.3  increase         True           False         False
# 97   1971q2   4861.9  increase         True           False          True
# 98   1971q3   4900.0  increase        False           False         False
# 99   1971q4   4914.3  increase        False           False         False
# 100  1972q1   5002.4  increase        False           False         False
# 101  1972q2   5118.3  increase        False           False         False
# 102  1972q3   5165.4  increase        False           False         False
# 103  1972q4   5251.2  increase        False           False         False
# 104  1973q1   5380.5  increase        False           False         False
# 105  1973q2   5441.5  increase        False           False         False
# 106  1973q3   5411.9   decline        False           False         False
# 107  1973q4   5462.4  increase        False           False         False
# 108  1974q1   5417.0   decline        False           False         False
# 109  1974q2   5431.3  increase        False           False         False
# 110  1974q3   5378.7   decline         True            True         False
# 111  1974q4   5357.2   decline         True           False         False
# 112  1975q1   5292.4   decline         True           False         False
# 113  1975q2   5333.2  increase         True           False         False
# 114  1975q3   5421.4  increase         True           False          True
# 115  1975q4   5494.4  increase        False           False         False
# 116  1976q1   5618.5  increase        False           False         False
# 117  1976q2   5661.0  increase        False           False         False
# 118  1976q3   5689.8  increase        False           False         False
# 119  1976q4   5732.5  increase        False           False         False
# 120  1977q1   5799.2  increase        False           False         False
# 121  1977q2   5913.0  increase        False           False         False
# 122  1977q3   6017.6  increase        False           False         False
# 123  1977q4   6018.2  increase        False           False         False
# 124  1978q1   6039.2  increase        False           False         False
# 125  1978q2   6274.0  increase        False           False         False
# 126  1978q3   6335.3  increase        False           False         False
# 127  1978q4   6420.3  increase        False           False         False
# 128  1979q1   6433.0  increase        False           False         False
# 129  1979q2   6440.8  increase        False           False         False
# 130  1979q3   6487.1  increase        False           False         False
# 131  1979q4   6503.9  increase        False           False         False
# 132  1980q1   6524.9  increase        False           False         False
# 133  1980q2   6392.6   decline         True            True         False
# 134  1980q3   6382.9   decline         True           False         False
# 135  1980q4   6501.2  increase         True           False         False
# 136  1981q1   6635.7  increase         True           False         False
# 137  1981q2   6587.3   decline         True           False         False
# 138  1981q3   6662.9  increase         True           False         False
# 139  1981q4   6585.1   decline         True           False         False
# 140  1982q1   6475.0   decline         True           False         False
# 141  1982q2   6510.2  increase         True           False         False
# 142  1982q3   6486.8   decline         True           False         False
# 143  1982q4   6493.1  increase         True           False         False
# 144  1983q1   6578.2  increase         True           False          True
# 145  1983q2   6728.3  increase        False           False         False
# 146  1983q3   6860.0  increase        False           False         False
# 147  1983q4   7001.5  increase        False           False         False
# 148  1984q1   7140.6  increase        False           False         False
# 149  1984q2   7266.0  increase        False           False         False
# 150  1984q3   7337.5  increase        False           False         False
# 151  1984q4   7396.0  increase        False           False         False
# 152  1985q1   7469.5  increase        False           False         False
# 153  1985q2   7537.9  increase        False           False         False
# 154  1985q3   7655.2  increase        False           False         False
# 155  1985q4   7712.6  increase        False           False         False
# 156  1986q1   7784.1  increase        False           False         False
# 157  1986q2   7819.8  increase        False           False         False
# 158  1986q3   7898.6  increase        False           False         False
# 159  1986q4   7939.5  increase        False           False         False
# 160  1987q1   7995.0  increase        False           False         False
# 161  1987q2   8084.7  increase        False           False         False
# 162  1987q3   8158.0  increase        False           False         False
# 163  1987q4   8292.7  increase        False           False         False
# 164  1988q1   8339.3  increase        False           False         False
# 165  1988q2   8449.5  increase        False           False         False
# 166  1988q3   8498.3  increase        False           False         False
# 167  1988q4   8610.9  increase        False           False         False
# 168  1989q1   8697.7  increase        False           False         False
# 169  1989q2   8766.1  increase        False           False         False
# 170  1989q3   8831.5  increase        False           False         False
# 171  1989q4   8850.2  increase        False           False         False
# 172  1990q1   8947.1  increase        False           False         False
# 173  1990q2   8981.7  increase        False           False         False
# 174  1990q3   8983.9  increase        False           False         False
# 175  1990q4   8907.4   decline         True            True         False
# 176  1991q1   8865.6   decline         True           False         False
# 177  1991q2   8934.4  increase         True           False         False
# 178  1991q3   8977.3  increase         True           False          True
# 179  1991q4   9016.4  increase        False           False         False
# 180  1992q1   9123.0  increase        False           False         False
# 181  1992q2   9223.5  increase        False           False         False
# 182  1992q3   9313.2  increase        False           False         False
# 183  1992q4   9406.5  increase        False           False         False
# 184  1993q1   9424.1  increase        False           False         False
# 185  1993q2   9480.1  increase        False           False         False
# 186  1993q3   9526.3  increase        False           False         False
# 187  1993q4   9653.5  increase        False           False         False
# 188  1994q1   9748.2  increase        False           False         False
# 189  1994q2   9881.4  increase        False           False         False
# 190  1994q3   9939.7  increase        False           False         False
# 191  1994q4  10052.5  increase        False           False         False
# 192  1995q1  10086.9  increase        False           False         False
# 193  1995q2  10122.1  increase        False           False         False
# 194  1995q3  10208.8  increase        False           False         False
# 195  1995q4  10281.2  increase        False           False         False
# 196  1996q1  10348.7  increase        False           False         False
# 197  1996q2  10529.4  increase        False           False         False
# 198  1996q3  10626.8  increase        False           False         False
# 199  1996q4  10739.1  increase        False           False         False
# 200  1997q1  10820.9  increase        False           False         False
# 201  1997q2  10984.2  increase        False           False         False
# 202  1997q3  11124.0  increase        False           False         False
# 203  1997q4  11210.3  increase        False           False         False
# 204  1998q1  11321.2  increase        False           False         False
# 205  1998q2  11431.0  increase        False           False         False
# 206  1998q3  11580.6  increase        False           False         False
# 207  1998q4  11770.7  increase        False           False         False
# 208  1999q1  11864.7  increase        False           False         False
# 209  1999q2  11962.5  increase        False           False         False
# 210  1999q3  12113.1  increase        False           False         False
# 211  1999q4  12323.3  increase        False           False         False
# 212  2000q1  12359.1  increase        False           False         False
# 213  2000q2  12592.5  increase        False           False         False
# 214  2000q3  12607.7  increase        False           False         False
# 215  2000q4  12679.3  increase        False           False         False
# 216  2001q1  12643.3   decline        False           False         False
# 217  2001q2  12710.3  increase        False           False         False
# 218  2001q3  12670.1   decline        False           False         False
# 219  2001q4  12705.3  increase        False           False         False
# 220  2002q1  12822.3  increase        False           False         False
# 221  2002q2  12893.0  increase        False           False         False
# 222  2002q3  12955.8  increase        False           False         False
# 223  2002q4  12964.0  increase        False           False         False
# 224  2003q1  13031.2  increase        False           False         False
# 225  2003q2  13152.1  increase        False           False         False
# 226  2003q3  13372.4  increase        False           False         False
# 227  2003q4  13528.7  increase        False           False         False
# 228  2004q1  13606.5  increase        False           False         False
# 229  2004q2  13706.2  increase        False           False         False
# 230  2004q3  13830.8  increase        False           False         False
# 231  2004q4  13950.4  increase        False           False         False
# 232  2005q1  14099.1  increase        False           False         False
# 233  2005q2  14172.7  increase        False           False         False
# 234  2005q3  14291.8  increase        False           False         False
# 235  2005q4  14373.4  increase        False           False         False
# 236  2006q1  14546.1  increase        False           False         False
# 237  2006q2  14589.6  increase        False           False         False
# 238  2006q3  14602.6  increase        False           False         False
# 239  2006q4  14716.9  increase        False           False         False
# 240  2007q1  14726.0  increase        False           False         False
# 241  2007q2  14838.7  increase        False           False         False
# 242  2007q3  14938.5  increase        False           False         False
# 243  2007q4  14991.8  increase        False           False         False
# 244  2008q1  14889.5   decline        False           False         False
# 245  2008q2  14963.4  increase        False           False         False
# 246  2008q3  14891.6   decline         True            True         False
# 247  2008q4  14577.0   decline         True           False         False
# 248  2009q1  14375.0   decline         True           False         False
# 249  2009q2  14355.6   decline         True           False         False
# 250  2009q3  14402.5  increase         True           False         False
# 251  2009q4  14541.9  increase         True           False          True
# 252  2010q1  14604.8  increase        False           False         False
# 253  2010q2  14745.9  increase        False           False         False
# 254  2010q3  14845.5  increase        False           False         False
# 255  2010q4  14939.0  increase        False           False         False
# 256  2011q1  14881.3   decline        False           False         False
# 257  2011q2  14989.6  increase        False           False         False
# 258  2011q3  15021.1  increase        False           False         False
# 259  2011q4  15190.3  increase        False           False         False
# 260  2012q1  15291.0  increase        False           False         False
# 261  2012q2  15362.4  increase        False           False         False
# 262  2012q3  15380.8  increase        False           False         False
# 263  2012q4  15384.3  increase        False           False         False
# 264  2013q1  15491.9  increase        False           False         False
# 265  2013q2  15521.6  increase        False           False         False
# 266  2013q3  15641.3  increase        False           False         False
# 267  2013q4  15793.9  increase        False           False         False
# 268  2014q1  15747.0   decline        False           False         False
# 269  2014q2  15900.8  increase        False           False         False
# 270  2014q3  16094.5  increase        False           False         False
# 271  2014q4  16186.7  increase        False           False         False
# 272  2015q1  16269.0  increase        False           False         False
# 273  2015q2  16374.2  increase        False           False         False
# 274  2015q3  16454.9  increase        False           False         False
# 275  2015q4  16490.7  increase        False           False         False
# 276  2016q1  16525.0  increase        False           False         False
# 277  2016q2  16583.1  increase        False           False         False

# %%
def get_recession_start(start = '2001q1'):
    '''Returns the year and quarter of the recession start time as a 
    string value in a format such as 2005q3'''
    
    gdp_df = get_list_of_GDP_recession()
    
    #get gdp_df after start date
    startrow = (gdp_df.loc[gdp_df['Quarter'] == start].index[0])
    gdp_df = gdp_df.iloc[startrow:]
    
    #return next recession start
    for index, row in gdp_df.iterrows():
        if row['Recession Start'] == True:
            return row['Quarter']

# %%
def get_recession_end(start = '2001q1'):
    '''Returns the year and quarter of the recession end time as a 
    string value in a format such as 2005q3'''
    
    recession_start = get_recession_start(start)
    gdp_df = get_list_of_GDP_recession()
    
    #get gdp_df after start date
    startrow = (gdp_df.loc[gdp_df['Quarter'] == recession_start].index[0])
    gdp_df = gdp_df.iloc[startrow:]
    
    #return end of recession
    for index, row in gdp_df.iterrows():
        if row['Recession End'] == True:
            return row['Quarter']

# %%
def get_recession_bottom(start = '2001q1'):
    '''Returns the year and quarter of the recession bottom time as a 
    string value in a format such as 2005q3'''

    gdp_df = get_list_of_GDP_recession()
    
    #get gdp_df from next recession start date to next recession end date
    startrow = (gdp_df.loc[gdp_df['Quarter'] == get_recession_start(start)].index[0])
    endrow = (gdp_df.loc[gdp_df['Quarter'] == get_recession_end(start)].index[0])
    gdp_df = gdp_df.iloc[startrow:endrow+1]
    
    #return recession bottom
    min = gdp_df['GDP'].min()
    return gdp_df.loc[gdp_df.loc[gdp_df['GDP'] == min].index[0]]['Quarter']

# %%
def convert_housing_data_to_quarters():
    '''Converts the housing data to quarters from 1996q1 through 2016q3, and returns it as mean 
    values in a dataframe.
    '''    
    # import
    hd_df = pd.read_csv('City_Zhvi_AllHomes.csv')
    
    # clean and format data
    hd_df.replace({"State": states}, inplace = True)
    hd_df.set_index(['State', 'RegionName'],inplace = True)
    hd_df.sort_index(inplace = True)
    
    hd_df = hd_df.iloc[:,4:]
    
    hd_df.columns = pd.to_datetime(hd_df.columns)
    hd_df = hd_df.resample('Q', axis=1).mean()
    hd_df = hd_df.rename(columns=lambda col: '{}q{}'.format(col.year, col.quarter))
    
    return hd_df

# %%
def run_ttest(start = '2001q1'):
    '''First creates new data showing the decline or growth of housing prices
    between the recession start and the recession bottom. Then runs a ttest
    comparing the university town values to the non-university towns values, 
    return whether the alternative hypothesis (that the two groups are the same)
    can be rejected or not as well as the p-value of the confidence. 
    
    Return the tuple (different, p, better) where different=True if the t-test is
    True at a p<0.01 (we reject the null hypothesis), or different=False if 
    otherwise (we cannot reject the null hypothesis). The variable p should
    be equal to the exact p value returned from scipy.stats.ttest_ind(). The
    value for better should be either "university town" or "non-university town"
    depending on which has a lower mean price ratio (which is equivilent to a
    reduced market loss).'''
    
    #creates new data showing the decline or growth of housing prices between the recession start and the recession bottom.
    ut_df = get_list_of_university_towns()
    hd_df = convert_housing_data_to_quarters()

    q_before_recession_start = pd.to_datetime(get_recession_start(start)) - pd.offsets.DateOffset(months=3)
    q_before_recession_start = '{}q{}'.format(q_before_recession_start.year, q_before_recession_start.quarter)

    bottom = get_recession_bottom(start)

    
    #new df includes hd_df indexes and quarters of start and bottom, a price ratio column, 
    #and a boolean column of whether it is a university town
    
    df = hd_df[[q_before_recession_start, bottom]]

    df['Price Ratio'] = df[q_before_recession_start] / df[bottom]
    
        # merge university town data to add boolean column 'Is UT'
    ut_df['Is UT'] = True
    ut_df.set_index('State', inplace = True)

    ut_df.reset_index(inplace = True)
    ut_df.set_index(['State','RegionName'],inplace = True)

    df = df.merge(ut_df, how = 'left', left_index = True, right_index = True)
    df['Is UT'].fillna(False, inplace = True)
    

    #run a ttest comparing the university town values to the non-university towns values
    ut = df[df['Is UT'] == True]
    notut = df[df['Is UT'] == False]

    from scipy import stats
    ttest = stats.ttest_ind(ut['Price Ratio'].dropna(), notut['Price Ratio'].dropna())
    ttest

    
    #return a tuple stating whether the alternative hypothesis (that the two groups are the same) is true or not, 
    #the p-value of the confidence, and which subset maintains better price ratio in recession.

    if ut['Price Ratio'].mean() < notut['Price Ratio'].mean():
        better = 'university town'
    elif ut['Price Ratio'].mean() > notut['Price Ratio'].mean():
        better = 'not university town'
    else:
        better = 'neither'

    return (ttest[1] <= .05, ttest[1], better)

# %%
run_ttest()
# Out:
# (True, 0.002724063704761164, 'university town')
